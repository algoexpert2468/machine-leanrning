# %% [markdown]
# <a href="https://colab.research.google.com/github/algoexpert2468/machine-leanrning/blob/main/matplotlib_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
titanic=pd.read_csv('/content/gdrive/MyDrive/titanic.csv')
titanic
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    male  22.0                 1                 0
# 1           1       1  female  38.0                 1                 0
# 2           1       3  female  26.0                 0                 0
# 3           1       1  female  35.0                 1                 0
# 4           0       3    male  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 882         0       2    male  27.0                 0                 0
# 883         1       1  female  19.0                 0                 0
# 884         0       3  female   7.0                 1                 2
# 885         1       1    male  26.0                 0                 0
# ...

# %%
titanic["dates"]=pd.date_range("1/1/2020",periods=len(titanic))
titanic
# Out:
#      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    male  22.0                 1                 0
# 1           1       1  female  38.0                 1                 0
# 2           1       3  female  26.0                 0                 0
# 3           1       1  female  35.0                 1                 0
# 4           0       3    male  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 882         0       2    male  27.0                 0                 0
# 883         1       1  female  19.0                 0                 0
# 884         0       3  female   7.0                 1                 2
# 885         1       1    male  26.0                 0                 0
# 886         0       3    male  32.0                 0                 0
#
#         Fare      dates
# 0     7.2500 2020-01-01
# 1    71.2833 2020-01-02
# 2     7.9250 2020-01-03
# ...

# %%
titanic["cumfare"]=titanic["Fare"].cumsum()
titanic
# Out:
#      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    male  22.0                 1                 0
# 1           1       1  female  38.0                 1                 0
# 2           1       3  female  26.0                 0                 0
# 3           1       1  female  35.0                 1                 0
# 4           0       3    male  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 882         0       2    male  27.0                 0                 0
# 883         1       1  female  19.0                 0                 0
# 884         0       3  female   7.0                 1                 2
# 885         1       1    male  26.0                 0                 0
# 886         0       3    male  32.0                 0                 0
#
#         Fare      dates     cumfare
# 0     7.2500 2020-01-01      7.2500
# ...

# %%
titanic.plot(x="dates", y="cumfare")

# %%
titanic.plot(x="dates",y="Age",kind="scatter")

# %% [markdown]
# ## ***matplotlib part 2***

# %%
import numpy as np
x=np.random.randn(10,4)
x
# Out:
# array([[-0.13336403, -2.18998203,  0.81003533, -1.37213916],
#        [-1.60033701, -1.14877658, -0.35735287,  0.60596387],
#        [ 0.03174911, -0.74866915,  0.48032846,  2.1496849 ],
#        [-1.05277487,  0.64059952,  0.01678909,  0.3111695 ],
#        [ 0.87961814,  0.61638632,  1.92615148, -1.18861285],
#        [-1.09051417, -0.5580155 ,  0.49955745,  0.90497598],
#        [ 1.35111698,  1.74538434, -0.62923332,  0.24446613],
#        [ 1.13082981, -0.85693779,  1.79659896,  0.8019954 ],
#        [-0.29235228,  0.1970041 ,  0.28435152, -0.58595798],
#        [ 1.73101642, -1.05760052,  2.52571813,  2.47853154]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.133364 -2.189982  0.810035 -1.372139
# 1 -1.600337 -1.148777 -0.357353  0.605964
# 2  0.031749 -0.748669  0.480328  2.149685
# 3 -1.052775  0.640600  0.016789  0.311170
# 4  0.879618  0.616386  1.926151 -1.188613
# 5 -1.090514 -0.558016  0.499557  0.904976
# 6  1.351117  1.745384 -0.629233  0.244466
# 7  1.130830 -0.856938  1.796599  0.801995
# 8 -0.292352  0.197004  0.284352 -0.585958
# 9  1.731016 -1.057601  2.525718  2.478532

# %%
df.plot.bar()

# %%
df.plot.hist()

# %%
titanic.plot(x="Age",y="Pclass",kind="bar")

# %%
titanic["Fare"].plot.hist()

# %%
titanic["Fare"].plot.hist(bins=100)

# %% [markdown]
# ## ***Heart disease***

# %%
heart=pd.read_csv('/content/gdrive/MyDrive/heart.csv')
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart["age"].plot.hist(bins=100)

# %%
heart.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
heart.plot.hist(figsize=(10,30), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbff6011310>,
# ...
#       dtype=object)

# %%
heart.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
over50=heart[heart["age"]>50]
over50.head(10)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
#
#     slope  ca  thal  target
# 0       2   2     3       0
# 1       0   0     3       0
# 2       0   0     3       0
# 3       2   1     3       0
# 4       1   3     2       0
# ...

# %%
over50.plot(kind='scatter',x='age',y='chol',c='target')

# %%
import matplotlib.pyplot as plt
fix,ax=plt.subplots(figsize=(10,6))
over50.plot(kind='scatter',x='age',y='chol',c='target',ax=ax)

# %%
fig,ax=plt.subplots(figsize=(10,6))
scatter=ax.scatter(x=over50["age"],y=over50["chol"],c=over50["target"])
ax.set(title="heart disease",xlabel="age",ylabel="chol")
ax.legend(*scatter.legend_elements(),title="target")
ax.axhline(over50["chol"].mean(),linestyle='--')
