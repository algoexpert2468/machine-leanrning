# %% [markdown]
# <a href="https://colab.research.google.com/github/algoexpert2468/machine-leanrning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
titanic=pd.read_csv('/content/gdrive/MyDrive/titanic.csv')
titanic.head()
titanic.dtypes
titanic.columns
titanic_columns=titanic.columns

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=887, step=1)

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses  Parents/Children  \
# count  887.000000  887.000000  887.000000        887.000000        887.000000
# mean     0.385569    2.305524   29.471443          0.525366          0.383315
# std      0.487004    0.836662   14.121908          1.104669          0.807466
# min      0.000000    1.000000    0.420000          0.000000          0.000000
# 25%      0.000000    2.000000   20.250000          0.000000          0.000000
# 50%      0.000000    3.000000   28.000000          0.000000          0.000000
# 75%      1.000000    3.000000   38.000000          1.000000          0.000000
# max      1.000000    3.000000   80.000000          8.000000          6.000000
#
#             Fare
# count  887.00000
# mean    32.30542
# std     49.78204
# min      0.00000
# 25%      7.92500
# 50%     14.45420
# 75%     31.13750
# max    512.32920

# %% [markdown]
# titanic.info()

# %%
titanic.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Survived             0.385569
# Pclass               2.305524
# Age                 29.471443
# Siblings/Spouses     0.525366
# Parents/Children     0.383315
# Fare                32.305420
# dtype: float64

# %%
titanic_deaths=pd.Series([100,200,300])
titanic_deaths.mean()
# Out:
# 200.0

# %%
titanic.sum()
# Out:
# Survived                                                          342
# Pclass                                                           2045
# Sex                 malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                          26141.17
# Siblings/Spouses                                                  466
# Parents/Children                                                  340
# Fare                                                       28654.9077
# dtype: object

# %% [markdown]
# titanic["Pclass"].sum()

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    male  22.0                 1                 0
# 1           1       1  female  38.0                 1                 0
# 2           1       3  female  26.0                 0                 0
# 3           1       1  female  35.0                 1                 0
# 4           0       3    male  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 882         0       2    male  27.0                 0                 0
# 883         1       1  female  19.0                 0                 0
# 884         0       3  female   7.0                 1                 2
# 885         1       1    male  26.0                 0                 0
# 886         0       3    male  32.0                 0                 0
#
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# ...

# %% [markdown]
# titanic.head()

# %%
titanic.tail(10)
# Out:
#      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 877         0       3    male  33.0                 0                 0
# 878         0       3  female  22.0                 0                 0
# 879         0       2    male  28.0                 0                 0
# 880         0       3    male  25.0                 0                 0
# 881         0       3  female  39.0                 0                 5
# 882         0       2    male  27.0                 0                 0
# 883         1       1  female  19.0                 0                 0
# 884         0       3  female   7.0                 1                 2
# 885         1       1    male  26.0                 0                 0
# 886         0       3    male  32.0                 0                 0
#
#         Fare
# 877   7.8958
# 878  10.5167
# 879  10.5000
# 880   7.0500
# 881  29.1250
# 882  13.0000
# 883  30.0000
# 884  23.4500
# 885  30.0000
# 886   7.7500

# %%
animals=pd.Series(["bird","panda","camel","horse","monkey"],index=[0,4,2,6,9])
animals
# Out:
# 0      bird
# 4     panda
# 2     camel
# 6     horse
# 9    monkey
# dtype: object

# %%
animals.loc[9]
# Out:
# 'monkey'

# %%
animals.iloc[2]
# Out:
# 'camel'

# %%
animals.iloc[:3]
# Out:
# 0     bird
# 4    panda
# 2    camel
# dtype: object

# %%
titanic.loc[:4]
# Out:
#    Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children     Fare
# 0         0       3    male  22.0                 1                 0   7.2500
# 1         1       1  female  38.0                 1                 0  71.2833
# 2         1       3  female  26.0                 0                 0   7.9250
# 3         1       1  female  35.0                 1                 0  53.1000
# 4         0       3    male  35.0                 0                 0   8.0500

# %%
titanic.head(4)
# Out:
#    Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children     Fare
# 0         0       3    male  22.0                 1                 0   7.2500
# 1         1       1  female  38.0                 1                 0  71.2833
# 2         1       3  female  26.0                 0                 0   7.9250
# 3         1       1  female  35.0                 1                 0  53.1000

# %%
titanic["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 882      male
# 883    female
# 884    female
# 885      male
# 886      male
# Name: Sex, Length: 887, dtype: object

# %%
titanic.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 882      male
# 883    female
# 884    female
# 885      male
# 886      male
# Name: Sex, Length: 887, dtype: object

# %%
titanic[titanic["Sex"]=="male"]
# Out:
#      Survived  Pclass   Sex   Age  Siblings/Spouses  Parents/Children     Fare
# 0           0       3  male  22.0                 1                 0   7.2500
# 4           0       3  male  35.0                 0                 0   8.0500
# 5           0       3  male  27.0                 0                 0   8.4583
# 6           0       1  male  54.0                 0                 0  51.8625
# 7           0       3  male   2.0                 3                 1  21.0750
# ..        ...     ...   ...   ...               ...               ...      ...
# 879         0       2  male  28.0                 0                 0  10.5000
# 880         0       3  male  25.0                 0                 0   7.0500
# 882         0       2  male  27.0                 0                 0  13.0000
# 885         1       1  male  26.0                 0                 0  30.0000
# 886         0       3  male  32.0                 0                 0   7.7500
#
# [573 rows x 7 columns]

# %%
titanic[titanic["Age"]>20]
# Out:
#      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    male  22.0                 1                 0
# 1           1       1  female  38.0                 1                 0
# 2           1       3  female  26.0                 0                 0
# 3           1       1  female  35.0                 1                 0
# 4           0       3    male  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 880         0       3    male  25.0                 0                 0
# 881         0       3  female  39.0                 0                 5
# 882         0       2    male  27.0                 0                 0
# 885         1       1    male  26.0                 0                 0
# 886         0       3    male  32.0                 0                 0
#
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# ...

# %%
titanic.groupby(["Sex"]).mean()
# Out:
#         Survived    Pclass        Age  Siblings/Spouses  Parents/Children  \
# Sex
# female  0.742038  2.159236  27.719745          0.694268          0.649682
# male    0.190227  2.385689  30.431361          0.432810          0.237347
#
#              Fare
# Sex
# female  44.479818
# male    25.633935

# %%
titanic["Fare"].plot()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
titanic["Fare"].hist()

# %%
titanic["Sex"].str.lower()
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 882      male
# 883    female
# 884    female
# 885      male
# 886      male
# Name: Sex, Length: 887, dtype: object

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    male  22.0                 1                 0
# 1           1       1  female  38.0                 1                 0
# 2           1       3  female  26.0                 0                 0
# 3           1       1  female  35.0                 1                 0
# 4           0       3    male  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 882         0       2    male  27.0                 0                 0
# 883         1       1  female  19.0                 0                 0
# 884         0       3  female   7.0                 1                 2
# 885         1       1    male  26.0                 0                 0
# 886         0       3    male  32.0                 0                 0
#
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# ...

# %%
titanic["Sex"]=titanic["Sex"].str.upper()

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    MALE  22.0                 1                 0
# 1           1       1  FEMALE  38.0                 1                 0
# 2           1       3  FEMALE  26.0                 0                 0
# 3           1       1  FEMALE  35.0                 1                 0
# 4           0       3    MALE  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 882         0       2    MALE  27.0                 0                 0
# 883         1       1  FEMALE  19.0                 0                 0
# 884         0       3  FEMALE   7.0                 1                 2
# 885         1       1    MALE  26.0                 0                 0
# 886         0       3    MALE  32.0                 0                 0
#
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# ...

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    MALE  22.0                 1                 0
# 1           1       1  FEMALE  38.0                 1                 0
# 2           1       3  FEMALE  26.0                 0                 0
# 3           1       1  FEMALE  35.0                 1                 0
# 4           0       3    MALE  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 882         0       2    MALE  27.0                 0                 0
# 883         1       1  FEMALE  19.0                 0                 0
# 884         0       3  FEMALE   7.0                 1                 2
# 885         1       1    MALE  26.0                 0                 0
# 886         0       3    MALE  32.0                 0                 0
#
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# ...

# %%
cars=pd.read_csv('/content/gdrive/MyDrive/cars.csv')
cars
# Out:
#              Unnamed: 0   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8  4.0    NaN   93.0  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02   0   0
# 5               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3  8.0    NaN  245.0  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2  6.0  167.6    NaN  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8  6.0  167.6  123.0  3.92  3.920  18.90   1   0
# ...

# %%
cars["disp"].fillna(cars["disp"]).mean()
# Out:
# 234.30714285714288

# %%
cars
# Out:
#              Unnamed: 0   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8  4.0    NaN   93.0  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02   0   0
# 5               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3  8.0    NaN  245.0  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8  4.0  140.8   95.0  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2  6.0  167.6    NaN  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8  6.0  167.6  123.0  3.92  3.920  18.90   1   0
# ...

# %%
cars["disp"].fillna(cars["disp"].mean())
# Out:
# 0     160.000000
# 1     160.000000
# 2     234.307143
# 3     258.000000
# 4     360.000000
# 5     225.000000
# 6     234.307143
# 7     146.700000
# 8     140.800000
# 9     167.600000
# 10    167.600000
# 11    275.800000
# 12    234.307143
# 13    275.800000
# 14    472.000000
# 15    460.000000
# 16    440.000000
# 17    234.307143
# 18     75.700000
# 19     71.100000
# 20    120.100000
# 21    318.000000
# 22    304.000000
# 23    350.000000
# 24    400.000000
# 25     79.000000
# 26    120.300000
# 27     95.100000
# 28    351.000000
# 29    145.000000
# 30    301.000000
# 31    121.000000
# Name: disp, dtype: float64

# %%
cars["disp"]=cars["disp"].fillna(cars["disp"].mean())
cars
# Out:
#              Unnamed: 0   mpg  cyl        disp     hp  drat     wt   qsec  vs  \
# 0             Mazda RX4  21.0  6.0  160.000000  110.0  3.90  2.620  16.46   0
# 1         Mazda RX4 Wag  21.0  6.0  160.000000  110.0  3.90  2.875  17.02   0
# 2            Datsun 710  22.8  4.0  234.307143   93.0  3.85  2.320  18.61   1
# 3        Hornet 4 Drive  21.4  6.0  258.000000  110.0  3.08  3.215  19.44   1
# 4     Hornet Sportabout  18.7  8.0  360.000000  175.0  3.15  3.440  17.02   0
# 5               Valiant  18.1  6.0  225.000000  105.0  2.76  3.460  20.22   1
# 6            Duster 360  14.3  8.0  234.307143  245.0  3.21  3.570  15.84   0
# 7             Merc 240D  24.4  4.0  146.700000   62.0  3.69  3.190  20.00   1
# 8              Merc 230  22.8  4.0  140.800000   95.0  3.92  3.150  22.90   1
# 9              Merc 280  19.2  6.0  167.600000    NaN  3.92  3.440  18.30   1
# 10            Merc 280C  17.8  6.0  167.600000  123.0  3.92  3.920  18.90   1
# ...

# %%
cars=cars.dropna()
cars
# Out:
#              Unnamed: 0   mpg  cyl        disp     hp  drat     wt   qsec  vs  \
# 0             Mazda RX4  21.0  6.0  160.000000  110.0  3.90  2.620  16.46   0
# 1         Mazda RX4 Wag  21.0  6.0  160.000000  110.0  3.90  2.875  17.02   0
# 2            Datsun 710  22.8  4.0  234.307143   93.0  3.85  2.320  18.61   1
# 3        Hornet 4 Drive  21.4  6.0  258.000000  110.0  3.08  3.215  19.44   1
# 4     Hornet Sportabout  18.7  8.0  360.000000  175.0  3.15  3.440  17.02   0
# 5               Valiant  18.1  6.0  225.000000  105.0  2.76  3.460  20.22   1
# 6            Duster 360  14.3  8.0  234.307143  245.0  3.21  3.570  15.84   0
# 7             Merc 240D  24.4  4.0  146.700000   62.0  3.69  3.190  20.00   1
# 8              Merc 230  22.8  4.0  140.800000   95.0  3.92  3.150  22.90   1
# 10            Merc 280C  17.8  6.0  167.600000  123.0  3.92  3.920  18.90   1
# 11           Merc 450SE  16.4  8.0  275.800000  180.0  3.07  4.070  17.40   0
# ...
