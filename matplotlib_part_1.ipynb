# %% [markdown]
# <a href="https://colab.research.google.com/github/algoexpert2468/machine-leanrning/blob/main/matplotlib_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***matplotlib***

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4])

# %%
x=[1,2,3,4]
y=[2,4,6,8]
plt.plot(x,y)

# %%
fig,ax=plt.subplots()
ax.plot(x,[10,50,100,300]);

# %% [markdown]
# ## ***matplotlib workflow***

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[1,2,3,4,5]
y=[6,7,8,9,10]

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax.plot(x,y)
ax.set(title="simple plot",xlabel="x axis",ylabel="y axis")
# Out:
# [Text(0, 0.5, 'y axis'), Text(0.5, 0, 'x axis'), Text(0.5, 1.0, 'simple plot')]

# %% [markdown]
# ### ***making plots using numpy arrays***

# %%
import numpy as np
x=np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2)

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %%
nut_butter_prices={"almonds":10,"cashew":8,"peanuts":12}
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="butterstore",ylabel="prices in ($)")
# Out:
# [Text(0, 0.5, 'prices in ($)'), Text(0.5, 1.0, 'butterstore')]

# %%
fig,ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
x=np.random.randn(1000)
fig,ax=plt.subplots()
ax.hist(x)
# Out:
# (array([  9.,  17.,  74., 168., 226., 234., 165.,  74.,  25.,   8.]),
#  array([-3.28613727, -2.62987108, -1.9736049 , -1.31733871, -0.66107252,
#         -0.00480634,  0.65145985,  1.30772604,  1.96399222,  2.62025841,
#          3.2765246 ]),
#  <a list of 10 Patch objects>)

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  2.,  18.,  53., 122., 248., 231., 192., 100.,  23.,  11.]),
#  array([-3.34709761, -2.71223511, -2.07737261, -1.44251011, -0.80764761,
#         -0.17278511,  0.46207739,  1.09693989,  1.73180239,  2.36666489,
#          3.00152739]),
#  <a list of 10 Patch objects>)

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax[1,1].hist(np.random.randn(1000))
# Out:
# (array([  5.,  17.,  59., 137., 227., 263., 173.,  82.,  30.,   7.]),
#  array([-3.18155003, -2.57521429, -1.96887855, -1.36254281, -0.75620707,
#         -0.14987133,  0.45646441,  1.06280015,  1.66913589,  2.27547163,
#          2.88180737]),
#  <a list of 10 Patch objects>)
